# %%
import requests
import csv
import pandas as pd
import io

http_proxy="http://10.144.1.10:8080"
https_proxy="http://10.144.1.10:8080"
proxyDict={
    "http": http_proxy,
    "https": https_proxy
}

# %%
list_ =[]
frame = pd.DataFrame()
def getdataframes(frame):
    firms = {"NDAQ","^SP500TR","BK","BFED","BLK","CARV","C","CME","EVR","FII","FIG","GBL","LAZ","NTRS","BPOP","PFS","STT","BX","BX"}
    returns = pd.DataFrame()
    for x in firms:
        request = 'http://chart.finance.yahoo.com/table.csv?s={}&a=10&b=21&c=2008&d=11&e=10&f=2008&g=d&ignore=.csv'.format(str(x))
        print (request)
        y = pd.read_csv(io.StringIO(requests.get(request,proxies=proxyDict).content.decode('utf-8')),usecols=['Adj Close','Date'])
        y.rename(columns={"Adj Close" : str(x)},inplace=True)
        y.set_index('Date')
        list_.append(y)
        frame=pd.concat(list_, axis=1,join='inner')
        print (y)
    return frame

# %%
returns = getdataframes(frame)
returns
# Out:
# http://chart.finance.yahoo.com/table.csv?s=STT&a=10&b=21&c=2008&d=11&e=10&f=2008&g=d&ignore=.csv
#           Date        STT
# 0   2008-12-10  37.144048
# 1   2008-12-09  37.179628
# 2   2008-12-08  39.020820
# 3   2008-12-05  35.827641
# 4   2008-12-04  33.194826
# 5   2008-12-03  32.554410
# 6   2008-12-02  32.847935
# 7   2008-12-01  31.513738
# 8   2008-11-28  37.455363
# 9   2008-11-26  36.156745
# 10  2008-11-25  33.577296
# 11  2008-11-24  32.100785
# 12  2008-11-21  28.267192
# http://chart.finance.yahoo.com/table.csv?s=PFS&a=10&b=21&c=2008&d=11&e=10&f=2008&g=d&ignore=.csv
#           Date        PFS
# 0   2008-12-10  10.591806
# 1   2008-12-09  10.944617
# 2   2008-12-08  11.019683
# 3   2008-12-05  10.689392
# 4   2008-12-04  10.126398
# 5   2008-12-03  10.501727
# 6   2008-12-02  10.208971
# 7   2008-12-01   9.458311
# 8   2008-11-28  11.252387
# 9   2008-11-26  11.229867
# 10  2008-11-25  11.079736
# 11  2008-11-24  11.319946
# 12  2008-11-21  10.028812
# ...

# %%
newreturns = returns.groupby(['Date'])
newreturns
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-204-6206f9a537a1> in <module>()
# ----> 1 newreturns = returns.groupby(['Date'])
#       2 newreturns
#
# C:\Users\lianos\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, **kwargs)
#    3776         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    3777                        sort=sort, group_keys=group_keys, squeeze=squeeze,
# -> 3778                        **kwargs)
#    3779
#    3780     def asfreq(self, freq, method=None, how=None, normalize=False):
#
# C:\Users\lianos\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\groupby.py in groupby(obj, by, **kwds)
#    1425         raise TypeError('invalid type: %s' % type(obj))
#    1426
# -> 1427     return klass(obj, by, **kwds)
# ...
