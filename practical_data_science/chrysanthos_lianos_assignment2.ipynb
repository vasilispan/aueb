# %%
import requests
import csv
import pandas as pd
import io
import statsmodels.api as sm
import statsmodels.formula.api as smf
import statsmodels.graphics as sgr
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as sc
from matplotlib.collections import LineCollection
from statsmodels.stats.outliers_influence import summary_table

# %% [markdown]
#  QUESTION 1

# %% [markdown]
# Function getdataframes returns a dataframe containing all firms plus the SP500TR index. We keep the 'Adj Close' column
# as it appears in finance.yahoo.com, and combine each dataframe a on common 'Date' axis.

# %%
def getdataframes():
    list_ =[]
    firms = {"NDAQ","^SP500TR","BK","BFED","BLK","CARV","C","CME","EVR","FII","FIG","GBL","LAZ","NTRS","BPOP","PFS","STT","BX","BX"}
    frame = pd.DataFrame()
    for x in firms:
        request = 'http://chart.finance.yahoo.com/table.csv?s={}&a=10&b=21&c=2008&d=11&e=10&f=2008&g=d&ignore=.csv'.format(str(x))
        y = pd.read_csv(io.StringIO(requests.get(request).content.decode('utf-8')),usecols=['Adj Close','Date'],index_col=0)
        y.rename(columns={"Adj Close" : str(x)},inplace=True)
        list_.append(y)
    frame=pd.concat(list_, axis=1,join='outer')
    frame = frame.rename(columns={"^SP500TR": "SP500"})
    return frame

# %%
returns = getdataframes()
returns
# Out:
#                   BX        EVR          C        STT        LAZ        FII  \
# 2008-11-21  2.823453   5.783971  37.017329  28.267192  17.594389  11.565914
# 2008-11-24  3.904259   6.255800  58.422574  32.100785  19.956206  12.432865
# 2008-11-25  3.910628   6.949971  59.699033  33.577296  20.148537  12.051932
# 2008-11-26  4.006165   8.536647  69.223386  36.156745  23.087346  12.485407
# 2008-11-28  3.987058   8.272201  81.398849  37.455363  24.048998  13.037103
# 2008-12-01  3.541220   8.230882  63.332034  31.513738  19.571545  11.670999
# 2008-12-02  3.401100   8.958108  70.892600  32.847935  19.533079  12.787526
# 2008-12-03  3.846937   8.958108  76.783952  32.554410  20.140843  13.464011
# 2008-12-04  3.649495   9.346513  72.660008  33.194826  19.309976  12.767823
# 2008-12-05  3.993427   9.916725  75.703872  35.827641  19.640785  14.035411
# 2008-12-08  4.388311  10.660479  83.166250  39.020820  22.479581  14.725030
# 2008-12-09  4.464740  10.809230  83.853579  37.179628  22.125693  14.830115
# 2008-12-10  4.197238  10.933189  81.497036  37.144048  22.687298  15.243887
#
#                  CARV        SP500       NTRS       NDAQ       BPOP  \
# 2008-11-21  87.436466  1282.589966  31.701180  15.678543  54.932721
# 2008-11-24  87.301947  1365.630005  36.672768  17.568534  57.793801
# 2008-11-25  81.290548  1374.790039  34.725913  17.801292  58.079912
# 2008-11-26  76.508751  1423.900024  37.107260  20.073003  58.652126
# 2008-11-28  76.508751  1437.680054  38.343890  20.017142  59.605819
# 2008-12-01  76.508751  1309.390015  32.921101  17.503361  51.117949
# 2008-12-02  76.508751  1361.790039  35.611605  18.639218  56.363261
# 2008-12-03  76.508751  1397.719971  38.059799  19.039561  58.366019
# 2008-12-04  76.508751  1356.810059  38.577846  20.240589  55.981786
# 2008-12-05  76.508751  1406.359985  42.262673  21.739547  55.791047
# 2008-12-08  76.508751  1460.599976  44.413616  23.713330  56.744740
# 2008-12-09  76.508751  1426.880005  42.103032  23.657469  53.597553
# 2008-12-10  88.121687  1444.000000  42.237466  23.648158  57.370663
#
#                   CME         BK        PFS        GBL         BLK    BFED  \
# 2008-11-21  25.959218  22.217093  10.028812  11.231554   88.556553  7.5340
# 2008-11-24  29.640884  27.728376  11.319946  11.945425   94.435924  7.4594
# 2008-11-25  29.527171  25.578890  11.079736  11.590653   95.493075     NaN
# 2008-11-26  31.272752  25.759446  11.229867  11.850242  101.429375  7.6834
# 2008-11-28  31.300810  25.974395  11.252387  11.867548  102.226299  8.1221
# 2008-12-01  25.495503  22.225691   9.458311   9.881692   87.603840  7.8421
# 2008-12-02  25.489597  23.334825  10.208971  10.106669   92.758935  7.5433
# 2008-12-03  26.920617  25.441323  10.501727  11.270493   99.665125  7.2352
# 2008-12-04  26.207322  24.538539  10.126398  10.976292   94.706413  7.8421
# 2008-12-05  28.734130  25.897015  10.689392  12.025923  104.992049  7.8421
# 2008-12-08  33.171564  26.438684  11.019683  12.564197  113.027454     NaN
# 2008-12-09  32.370836  23.756125  10.944617  11.985552  108.927920  7.5153
# 2008-12-10  32.886330  24.684703  10.591806  12.263661  108.600617     NaN
#
#                  FIG
# 2008-11-21  1.479990
# 2008-11-24  1.731445
# 2008-11-25  1.724260
# 2008-11-26  2.169694
# 2008-11-28  2.191248
# 2008-12-01  1.796105
# 2008-12-02  1.796105
# 2008-12-03  1.343486
# 2008-12-04  1.357855
# 2008-12-05  1.264458
# 2008-12-08  1.393777
# 2008-12-09  1.221351
# 2008-12-10  1.063294

# %% [markdown]
# Insert 'cumulative' column : sum of all firms minus the SP500

# %%
returns['cumulative'] = returns.sum(axis=1) - returns['SP500']
returns.sample()
# Out:
#                 BX       EVR        C        STT        LAZ        FII  \
# 2008-12-02  3.4011  8.958108  70.8926  32.847935  19.533079  12.787526
#
#                  CARV        SP500       NTRS       NDAQ       BPOP  \
# 2008-12-02  76.508751  1361.790039  35.611605  18.639218  56.363261
#
#                   CME         BK        PFS        GBL        BLK    BFED  \
# 2008-12-02  25.489597  23.334825  10.208971  10.106669  92.758935  7.5433
#
#                  FIG  cumulative
# 2008-12-02  1.796105  506.781585

# %%
mod = smf.ols("cumulative ~ SP500", data=returns)
rels = mod.fit()
rels.params
# Out:
# Intercept   -367.471325
# SP500          0.645168
# dtype: float64

# %%
rels.summary()
# Out:
# C:\Users\chrys\Anaconda3\lib\site-packages\scipy\stats\stats.py:1327: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=13
#   "anyway, n=%i" % int(n))
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             cumulative   R-squared:                       0.938
# Model:                            OLS   Adj. R-squared:                  0.932
# Method:                 Least Squares   F-statistic:                     166.0
# Date:                Wed, 30 Nov 2016   Prob (F-statistic):           5.58e-08
# Time:                        23:54:28   Log-Likelihood:                -46.205
# No. Observations:                  13   AIC:                             96.41
# Df Residuals:                      11   BIC:                             97.54
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept   -367.4713     69.564     -5.282      0.000      -520.581  -214.362
# SP500          0.6452      0.050     12.885      0.000         0.535     0.755
# ==============================================================================
# Omnibus:                        0.572   Durbin-Watson:                   1.168
# Prob(Omnibus):                  0.751   Jarque-Bera (JB):                0.568
# Skew:                          -0.387   Prob(JB):                        0.753
# Kurtosis:                       2.328   Cond. No.                     3.79e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.79e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
rels.resid
# Out:
# 2008-11-21    -0.206838
# 2008-11-24     3.080912
# 2008-11-25   -16.270945
# 2008-11-26   -13.952391
# 2008-11-28    -4.464482
# 2008-12-01     2.909060
# 2008-12-02    -4.331017
# 2008-12-03    -4.193098
# 2008-12-04    10.092856
# 2008-12-05     6.997222
# 2008-12-08    -1.425386
# 2008-12-09    12.744898
# 2008-12-10     9.019208
# dtype: float64

# %% [markdown]
# Now try an R^2 test and concatenate the residuals to the returns table

# %%
mod=sm.OLS(returns['cumulative'],returns['SP500'],data=returns)
res=mod.fit()
res.summary()
res.resid
# Out:
# C:\Users\chrys\Anaconda3\lib\site-packages\scipy\stats\stats.py:1327: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=13
#   "anyway, n=%i" % int(n))
# 2008-11-21   -28.648313
# 2008-11-24    -3.410405
# 2008-11-25   -20.340969
# 2008-11-26    -5.041064
# 2008-11-28     8.089350
# 2008-12-01   -18.448297
# 2008-12-02   -11.837361
# 2008-12-03    -2.202002
# 2008-12-04     1.270143
# 2008-12-05    11.272152
# 2008-12-08    17.186920
# 2008-12-09    22.443930
# 2008-12-10    23.243606
# dtype: float64

# %% [markdown]
# Run t-test and get the p-values (use scipy.stats library) to determine significant statistical difference between cumulative and SP500

# %%
sc.ttest_1samp(returns['cumulative'],returns['SP500'])[1]
# Out:
# array([  1.53193733e-17,   4.38441647e-18,   3.84857246e-18,
#          1.95808310e-18,   1.63066915e-18,   1.00840409e-17,
#          4.63263390e-18,   2.79396077e-18,   4.97746874e-18,
#          2.48177114e-18,   1.21008646e-18,   1.88167072e-18,
#          1.50079545e-18])

# %%
returns['stat_difference'] = sc.ttest_1samp(returns['cumulative'],returns['SP500'])[1]

# %%
returns
# Out:
#                   BX        EVR          C        STT        LAZ        FII  \
# 2008-11-21  2.823453   5.783971  37.017329  28.267192  17.594389  11.565914
# 2008-11-24  3.904259   6.255800  58.422574  32.100785  19.956206  12.432865
# 2008-11-25  3.910628   6.949971  59.699033  33.577296  20.148537  12.051932
# 2008-11-26  4.006165   8.536647  69.223386  36.156745  23.087346  12.485407
# 2008-11-28  3.987058   8.272201  81.398849  37.455363  24.048998  13.037103
# 2008-12-01  3.541220   8.230882  63.332034  31.513738  19.571545  11.670999
# 2008-12-02  3.401100   8.958108  70.892600  32.847935  19.533079  12.787526
# 2008-12-03  3.846937   8.958108  76.783952  32.554410  20.140843  13.464011
# 2008-12-04  3.649495   9.346513  72.660008  33.194826  19.309976  12.767823
# 2008-12-05  3.993427   9.916725  75.703872  35.827641  19.640785  14.035411
# 2008-12-08  4.388311  10.660479  83.166250  39.020820  22.479581  14.725030
# 2008-12-09  4.464740  10.809230  83.853579  37.179628  22.125693  14.830115
# 2008-12-10  4.197238  10.933189  81.497036  37.144048  22.687298  15.243887
#
#                  CARV        SP500       NTRS       NDAQ       BPOP  \
# 2008-11-21  87.436466  1282.589966  31.701180  15.678543  54.932721
schedule
personal
# Out:
#    Firm  Personal_Connections
# 0   BLK                     2
# 1  CARV                     1
# 2     C                     2
# 3   FIG                     1
# 4   GBL                     1
# 5  BPOR                     1
# 6    BX                     4
# 7  NASQ                     1

# %%
personal = pd.DataFrame({'Firm' : ['BLK','CARV','C','FIG','GBL','BPOR','BX','NASQ'], 'Personal_Connections':[2,1,2,1,1,1,4,1]})

# %% [markdown]
# Regression to estimate a and b of Return equation

# %%
firms = {"NDAQ","BK","BFED","BLK","CARV","C","CME","EVR","FII","FIG","GBL","LAZ","NTRS","BPOP","PFS","STT","BX","BX"}
for x in firms:
    mod = smf.ols("{} ~ SP500".format(str(x)), data=priorreturns)
    rels = mod.fit()
    print(rels.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BX   R-squared:                       0.757
# Model:                            OLS   Adj. R-squared:                  0.756
# Method:                 Least Squares   F-statistic:                     748.6
# Date:                Wed, 30 Nov 2016   Prob (F-statistic):           9.85e-76
# Time:                        23:54:32   Log-Likelihood:                -284.04
# No. Observations:                 242   AIC:                             572.1
# Df Residuals:                     240   BIC:                             579.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     -5.5607      0.592     -9.387      0.000        -6.728    -4.394
# SP500          0.0077      0.000     27.361      0.000         0.007     0.008
# ==============================================================================
# Omnibus:                        5.938   Durbin-Watson:                   0.167
# Prob(Omnibus):                  0.051   Jarque-Bera (JB):                6.083
# Skew:                          -0.383   Prob(JB):                       0.0478
# Kurtosis:                       2.873   Cond. No.                     2.46e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.46e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    EVR   R-squared:                       0.278
# Model:                            OLS   Adj. R-squared:                  0.275
# Method:                 Least Squares   F-statistic:                     92.56
# Date:                Wed, 30 Nov 2016   Prob (F-statistic):           9.67e-19
# Time:                        23:54:32   Log-Likelihood:                -580.06
# No. Observations:                 242   AIC:                             1164.
# Df Residuals:                     240   BIC:                             1171.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     -6.3554      2.013     -3.157      0.002       -10.321    -2.390
# SP500          0.0092      0.001      9.621      0.000         0.007     0.011
# ==============================================================================
# Omnibus:                       15.886   Durbin-Watson:                   0.031
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):                7.745
# Skew:                          -0.226   Prob(JB):                       0.0208
# Kurtosis:                       2.249   Cond. No.                     2.46e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.46e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      C   R-squared:                       0.597
# Model:                            OLS   Adj. R-squared:                  0.595
# Method:                 Least Squares   F-statistic:                     355.7
# Date:                Wed, 30 Nov 2016   Prob (F-statistic):           2.81e-49
# Time:                        23:54:32   Log-Likelihood:                -1166.3
# No. Observations:                 242   AIC:                             2337.
# Df Residuals:                     240   BIC:                             2344.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept   -208.3365     22.698     -9.179      0.000      -253.050  -163.623
# SP500          0.2037      0.011     18.859      0.000         0.182     0.225
# ==============================================================================
# Omnibus:                       28.475   Durbin-Watson:                   0.047
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               13.577
# Skew:                           0.391   Prob(JB):                      0.00113
# Kurtosis:                       2.143   Cond. No.                     2.46e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.46e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    STT   R-squared:                       0.664
# Model:                            OLS   Adj. R-squared:                  0.662
# Method:                 Least Squares   F-statistic:                     473.3
# Date:                Wed, 30 Nov 2016   Prob (F-statistic):           1.07e-58
# Time:                        23:54:32   Log-Likelihood:                -738.07
# No. Observations:                 242   AIC:                             1480.
# Df Residuals:                     240   BIC:                             1487.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept    -20.5588      3.867     -5.316      0.000       -28.177   -12.941
# SP500          0.0400      0.002     21.756      0.000         0.036     0.044
# ==============================================================================
# Omnibus:                      149.272   Durbin-Watson:                   0.126
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               18.221
# Skew:                           0.270   Prob(JB):                     0.000110
# Kurtosis:                       1.769   Cond. No.                     2.46e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.46e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    LAZ   R-squared:                       0.067
# Model:                            OLS   Adj. R-squared:                  0.063
# Method:                 Least Squares   F-statistic:                     17.33
# Date:                Wed, 30 Nov 2016   Prob (F-statistic):           4.39e-05
# Time:                        23:54:32   Log-Likelihood:                -571.15
# No. Observations:                 242   AIC:                             1146.
# Df Residuals:                     240   BIC:                             1153.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     21.1988      1.940     10.926      0.000        17.377    25.021
# SP500          0.0038      0.001      4.163      0.000         0.002     0.006
# ==============================================================================
# Omnibus:                        7.903   Durbin-Watson:                   0.137
# Prob(Omnibus):                  0.019   Jarque-Bera (JB):                6.377
# Skew:                           0.303   Prob(JB):                       0.0412
# Kurtosis:                       2.484   Cond. No.                     2.46e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.46e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    FII   R-squared:                       0.550
# Model:                            OLS   Adj. R-squared:                  0.548
# Method:                 Least Squares   F-statistic:                     293.7
# Date:                Wed, 30 Nov 2016   Prob (F-statistic):           1.55e-43
# Time:                        23:54:32   Log-Likelihood:                -473.87
# No. Observations:                 242   AIC:                             951.7
# Df Residuals:                     240   BIC:                             958.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     -0.6117      1.298     -0.471      0.638        -3.169     1.945
# SP500          0.0106      0.001     17.137      0.000         0.009     0.012
# ==============================================================================
# Omnibus:                       19.058   Durbin-Watson:                   0.106
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               10.330
# Skew:                           0.332   Prob(JB):                      0.00571
# Kurtosis:                       2.237   Cond. No.                     2.46e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.46e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   CARV   R-squared:                       0.455
# Model:                            OLS   Adj. R-squared:                  0.452
# Method:                 Least Squares   F-statistic:                     200.0
# Date:                Wed, 30 Nov 2016   Prob (F-statistic):           1.95e-33
# Time:                        23:54:32   Log-Likelihood:                -1152.2
# No. Observations:                 242   AIC:                             2308.
# Df Residuals:                     240   BIC:                             2315.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept   -157.7532     21.413     -7.367      0.000      -199.936  -115.571
# SP500          0.1441      0.010     14.142      0.000         0.124     0.164
# ==============================================================================
# Omnibus:                       70.413   Durbin-Watson:                   0.071
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               15.360
# Skew:                           0.288   Prob(JB):                     0.000462
# Kurtosis:                       1.908   Cond. No.                     2.46e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.46e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   NTRS   R-squared:                       0.318
# Model:                            OLS   Adj. R-squared:                  0.315
# Method:                 Least Squares   F-statistic:                     112.1
# Date:                Wed, 30 Nov 2016   Prob (F-statistic):           9.72e-22
# Time:                        23:54:32   Log-Likelihood:                -676.78
# No. Observations:                 242   AIC:                             1358.
# Df Residuals:                     240   BIC:                             1365.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     28.8868      3.002      9.622      0.000        22.973    34.800
# SP500          0.0151      0.001     10.586      0.000         0.012     0.018
# ==============================================================================
# Omnibus:                       38.662   Durbin-Watson:                   0.192
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               52.674
# Skew:                           1.028   Prob(JB):                     3.65e-12
# Kurtosis:                       4.000   Cond. No.                     2.46e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.46e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   NDAQ   R-squared:                       0.464
# Model:                            OLS   Adj. R-squared:                  0.462
# Method:                 Least Squares   F-statistic:                     207.6
# Date:                Wed, 30 Nov 2016   Prob (F-statistic):           2.46e-34
# Time:                        23:54:32   Log-Likelihood:                -705.27
# No. Observations:                 242   AIC:                             1415.
# Df Residuals:                     240   BIC:                             1422.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept    -14.3506      3.377     -4.249      0.000       -21.003    -7.698
# SP500          0.0232      0.002     14.410      0.000         0.020     0.026
# ==============================================================================
# Omnibus:                       28.697   Durbin-Watson:                   0.048
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               10.299
# Skew:                          -0.236   Prob(JB):                      0.00580
# Kurtosis:                       2.106   Cond. No.                     2.46e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.46e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   BPOP   R-squared:                       0.273
# Model:                            OLS   Adj. R-squared:                  0.270
# Method:                 Least Squares   F-statistic:                     90.20
# Date:                Wed, 30 Nov 2016   Prob (F-statistic):           2.30e-18
# Time:                        23:54:32   Log-Likelihood:                -1007.1
# No. Observations:                 242   AIC:                             2018.
# Df Residuals:                     240   BIC:                             2025.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept    -21.9963     11.752     -1.872      0.062       -45.147     1.154
# SP500          0.0531      0.006      9.497      0.000         0.042     0.064
# ==============================================================================
# Omnibus:                       66.841   Durbin-Watson:                   0.047
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               12.055
# Skew:                           0.034   Prob(JB):                      0.00241
# Kurtosis:                       1.909   Cond. No.                     2.46e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.46e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    CME   R-squared:                       0.451
# Model:                            OLS   Adj. R-squared:                  0.448
# Method:                 Least Squares   F-statistic:                     196.9
# Date:                Wed, 30 Nov 2016   Prob (F-statistic):           4.63e-33
# Time:                        23:54:32   Log-Likelihood:                -953.75
# No. Observations:                 242   AIC:                             1911.
# Df Residuals:                     240   BIC:                             1918.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept    -62.6374      9.429     -6.643      0.000       -81.211   -44.064
# SP500          0.0630      0.004     14.031      0.000         0.054     0.072
# ==============================================================================
# Omnibus:                      118.539   Durbin-Watson:                   0.029
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               16.247
# Skew:                           0.215   Prob(JB):                     0.000296
# Kurtosis:                       1.806   Cond. No.                     2.46e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.46e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BK   R-squared:                       0.774
# Model:                            OLS   Adj. R-squared:                  0.773
# Method:                 Least Squares   F-statistic:                     820.5
# Date:                Wed, 30 Nov 2016   Prob (F-statistic):           2.15e-79
# Time:                        23:54:32   Log-Likelihood:                -537.03
# No. Observations:                 242   AIC:                             1078.
# Df Residuals:                     240   BIC:                             1085.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept    -13.1622      1.685     -7.811      0.000       -16.482    -9.843
# SP500          0.0230      0.001     28.644      0.000         0.021     0.025
# ==============================================================================
# Omnibus:                        3.666   Durbin-Watson:                   0.165
# Prob(Omnibus):                  0.160   Jarque-Bera (JB):                2.840
# Skew:                           0.136   Prob(JB):                        0.242
# Kurtosis:                       2.544   Cond. No.                     2.46e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.46e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    PFS   R-squared:                       0.009
# Model:                            OLS   Adj. R-squared:                  0.005
# Method:                 Least Squares   F-statistic:                     2.226
# Date:                Wed, 30 Nov 2016   Prob (F-statistic):              0.137
# Time:                        23:54:32   Log-Likelihood:                -327.51
# No. Observations:                 242   AIC:                             659.0
# Df Residuals:                     240   BIC:                             666.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept      9.5490      0.709     13.470      0.000         8.152    10.945
# SP500          0.0005      0.000      1.492      0.137        -0.000     0.001
# ==============================================================================
# Omnibus:                        7.222   Durbin-Watson:                   0.212
# Prob(Omnibus):                  0.027   Jarque-Bera (JB):                7.641
# Skew:                           0.311   Prob(JB):                       0.0219
# Kurtosis:                       3.608   Cond. No.                     2.46e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.46e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    GBL   R-squared:                       0.414
# Model:                            OLS   Adj. R-squared:                  0.412
# Method:                 Least Squares   F-statistic:                     169.8
# Date:                Wed, 30 Nov 2016   Prob (F-statistic):           1.05e-29
# Time:                        23:54:32   Log-Likelihood:                -547.74
# No. Observations:                 242   AIC:                             1099.
# Df Residuals:                     240   BIC:                             1106.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     -0.5914      1.761     -0.336      0.737        -4.061     2.878
# SP500          0.0109      0.001     13.030      0.000         0.009     0.013
# ==============================================================================
# Omnibus:                       17.968   Durbin-Watson:                   0.128
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               19.883
# Skew:                           0.691   Prob(JB):                     4.81e-05
# Kurtosis:                       3.252   Cond. No.                     2.46e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.46e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    BLK   R-squared:                       0.346
# Model:                            OLS   Adj. R-squared:                  0.343
# Method:                 Least Squares   F-statistic:                     126.8
# Date:                Wed, 30 Nov 2016   Prob (F-statistic):           6.72e-24
# Time:                        23:54:32   Log-Likelihood:                -943.02
# No. Observations:                 242   AIC:                             1890.
# Df Residuals:                     240   BIC:                             1897.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     61.7271      9.020      6.843      0.000        43.959    79.495
# SP500          0.0483      0.004     11.262      0.000         0.040     0.057
# ==============================================================================
# Omnibus:                        7.983   Durbin-Watson:                   0.163
# Prob(Omnibus):                  0.018   Jarque-Bera (JB):                4.751
# Skew:                          -0.157   Prob(JB):                       0.0930
# Kurtosis:                       2.389   Cond. No.                     2.46e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.46e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   BFED   R-squared:                       0.569
# Model:                            OLS   Adj. R-squared:                  0.567
# Method:                 Least Squares   F-statistic:                     317.0
# Date:                Wed, 30 Nov 2016   Prob (F-statistic):           9.11e-46
# Time:                        23:54:32   Log-Likelihood:                -105.16
# No. Observations:                 242   AIC:                             214.3
# Df Residuals:                     240   BIC:                             221.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept      4.3778      0.283     15.477      0.000         3.821     4.935
# SP500          0.0024      0.000     17.803      0.000         0.002     0.003
# ==============================================================================
# Omnibus:                       15.190   Durbin-Watson:                   0.200
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):                8.401
# Skew:                          -0.280   Prob(JB):                       0.0150
# Kurtosis:                       2.279   Cond. No.                     2.46e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.46e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    FIG   R-squared:                       0.839
# Model:                            OLS   Adj. R-squared:                  0.838
# Method:                 Least Squares   F-statistic:                     1251.
# Date:                Wed, 30 Nov 2016   Prob (F-statistic):           3.62e-97
# Time:                        23:54:32   Log-Likelihood:                -280.64
# No. Observations:                 242   AIC:                             565.3
# Df Residuals:                     240   BIC:                             572.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept    -11.6809      0.584    -19.998      0.000       -12.832   -10.530
# SP500          0.0098      0.000     35.369      0.000         0.009     0.010
# ==============================================================================
# Omnibus:                        4.502   Durbin-Watson:                   0.272
# Prob(Omnibus):                  0.105   Jarque-Bera (JB):                4.543
# Skew:                           0.332   Prob(JB):                        0.103
# Kurtosis:                       2.903   Cond. No.                     2.46e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.46e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
